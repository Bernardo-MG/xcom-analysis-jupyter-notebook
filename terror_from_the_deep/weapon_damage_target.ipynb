# %% [markdown]
# # Weapon Damage by Target

# %% [markdown]
# ## Setting Up

# %%
import pandas as pd

# %run weapon_full_data.ipynb

# %% [markdown]
# ## Weapon Damages by Target

# %%
weapon_damages_targets = weapon_data_targets.groupby(["weapon", "target"]).mean()
weapon_damages_targets = weapon_damages_targets[["target_turn_damage_expected"]]
weapon_damages_targets = weapon_damages_targets.rename(columns={"target_turn_damage_expected": "turn_damage"})
weapon_damages_targets = weapon_damages_targets.sort_values(by=["turn_damage"])

# %% [markdown]
# ### Average

# %%
weapon_damages_targets_graph = weapon_damages_targets.groupby(["target"]).mean()
ax = weapon_damages_targets_graph.plot.bar(title="Damage to target on average", legend=False)
ax.xaxis.get_label().set_visible(False)
ax.set_ylabel("Damage")
# Out:
# Text(0, 0.5, 'Damage')

# %% [markdown]
# ### Kinetic Weapons

# %%
weapon_damages_targets_kinetic = weapon_damages_targets.loc[ ["dart_gun", "jet_harpoon", "gas_cannon", "hidro_jet_cannon"] ]
weapon_damages_targets_kinetic = weapon_damages_targets_kinetic.swaplevel().unstack()
weapon_damages_targets_kinetic = weapon_damages_targets_kinetic.sort_values(by=["target"])
ax = weapon_damages_targets_kinetic.plot.bar(title="Damage to target with kinetic weapons")
ax.legend(["Dart gun", "Jet harpoon", "Gas cannon", "Hydro-jet cannon"]);
ax.xaxis.get_label().set_visible(False)
ax.set_ylabel("Damage")
# Out:
# Text(0, 0.5, 'Damage')

# %% [markdown]
# ### Melee

# %%
weapon_damages_targets_kinetic = weapon_damages_targets.loc[ ["thermal_tazer", "vibro_blade", "thermic_lance", "heavy_thermic_lance"] ]
weapon_damages_targets_kinetic = weapon_damages_targets_kinetic.swaplevel().unstack()
weapon_damages_targets_kinetic = weapon_damages_targets_kinetic.sort_values(by=["target"])
ax = weapon_damages_targets_kinetic.plot.bar(title="Damage to target with kinetic weapons")
ax.legend(["Thermal tazer", "Vibro blade", "Thermic lance", "Heavy thermic lance"]);
ax.xaxis.get_label().set_visible(False)
ax.set_ylabel("Damage")
# Out:
# Text(0, 0.5, 'Damage')

# %% [markdown]
# ### Explosive

# %%
weapon_damages_targets_grenade = weapon_damages_targets.loc[ ["magna_blast_grenade", "particle_disturbance_grenade", "magna_pack_explosive", "sonic_pulser"] ]
weapon_damages_targets_grenade = weapon_damages_targets_grenade.swaplevel().unstack()
weapon_damages_targets_grenade = weapon_damages_targets_grenade.sort_values(by=["target"])
ax = weapon_damages_targets_grenade.plot.bar(title="Damage to target with grenades")
ax.legend(["Magna blast", "Particle disturbance", "Magna-pack", "Sonic pulser"]);
ax.xaxis.get_label().set_visible(False)
ax.set_ylabel("Damage")
# Out:
# Text(0, 0.5, 'Damage')

# %%
weapon_damages_targets_launcher = weapon_damages_targets.loc[ ["torpedo_launcher", "disruptor_pulse_launcher", "thermal_shok_launcher"] ]
weapon_damages_targets_launcher = weapon_damages_targets_launcher.swaplevel().unstack()
weapon_damages_targets_launcher = weapon_damages_targets_launcher.sort_values(by=["target"])
ax = weapon_damages_targets_launcher.plot.bar(title="Damage to target with launchers")
ax.legend(["Torpedo launcher", "Thermal shok launcher", "Disruptor pulse launcher"]);
ax.xaxis.get_label().set_visible(False)
ax.set_ylabel("Damage")
# Out:
# Text(0, 0.5, 'Damage')

# %% [markdown]
# ### Gauss

# %%
weapon_damages_targets_laser = weapon_damages_targets.loc[ ["gauss_pistol", "gauss_rifle", "heavy_gauss"] ]
weapon_damages_targets_laser = weapon_damages_targets_laser.swaplevel().unstack()
weapon_damages_targets_laser = weapon_damages_targets_laser.sort_values(by=["target"])
ax = weapon_damages_targets_laser.plot.bar(title="Damage to target with gauss")
ax.legend(["Gauss pistol", "Gauss rifle", "Heavy gauss"]);
ax.xaxis.get_label().set_visible(False)
ax.set_ylabel("Damage")
# Out:
# Text(0, 0.5, 'Damage')

# %% [markdown]
# ### Sonic

# %%
weapon_damages_targets_plasma = weapon_damages_targets.loc[ ["sonic_pistol", "sonic_blasta_rifle", "sonic_cannon"] ]
weapon_damages_targets_plasma = weapon_damages_targets_plasma.swaplevel().unstack()
weapon_damages_targets_plasma = weapon_damages_targets_plasma.sort_values(by=["target"])
ax = weapon_damages_targets_plasma.plot.bar(title="Damage to target with sonic")
ax.legend(["Sonic pistol", "Sonic-blasta rifle", "Sonic cannon"]);
ax.xaxis.get_label().set_visible(False)
ax.set_ylabel("Damage")
# Out:
# Text(0, 0.5, 'Damage')

# %% [markdown]
# ### Tank

# %%
weapon_damages_targets_tank = weapon_damages_targets.loc[ ["aqua_jet_cannon_turret", "gas_cannon_turret", "gauss_cannon_turret", "sonic_cannon_turret", "pwt_cannon_turret"] ]
weapon_damages_targets_tank = weapon_damages_targets_tank.swaplevel().unstack()
weapon_damages_targets_tank = weapon_damages_targets_tank.sort_values(by=["target"])
ax = weapon_damages_targets_tank.plot.bar(title="Damage to target with turrets")
ax.legend(["Aqua jet", "Gas cannon", "Gauss", "Sonic", "PWT"]);
ax.xaxis.get_label().set_visible(False)
ax.set_ylabel("Damage")
# Out:
# Text(0, 0.5, 'Damage')

# %% [markdown]
# ### Target Damage Lists

# %% [markdown]
# #### Averages

# %%
weapon_damages_average = weapon_damages_targets.groupby(["weapon"]).mean()
weapon_damages_average = weapon_damages_average.sort_values(by=["turn_damage"])

# %%
weapon_damages_max = weapon_damages_targets.groupby(["weapon"]).max()
weapon_damages_max = weapon_damages_max.sort_values(by=["turn_damage"])

# %%
average_damages_expected = weapon_damages_max.merge(weapon_damages_average, on="weapon")
average_damages_expected = average_damages_expected.rename(columns={"turn_damage_x": "max", "turn_damage_y": "average"})
average_damages_expected = average_damages_expected.sort_values(by=["average"])
average_damages_expected
# Out:
#                                      max     average
# weapon
# jet_harpoon                     8.250000    6.983036
# dart_gun                       15.840000   13.407429
# magna_blast_grenade            26.812500   15.704464
# particle_disturbance_grenade   37.537500   21.986250
# hidro_jet_cannon               44.916667   28.288333
# gas_cannon                     39.558750   29.761875
# heavy_gauss                    39.187500   31.070089
# magna_pack_explosive           53.625000   31.408929
# aqua_jet_cannon_turret         60.328125   35.335045
# gauss_pistol                   47.025000   37.284107
# sonic_pulser                   64.350000   37.690714
# gas_cannon_turret              44.550000   37.708393
# torpedo_launcher               64.487500   40.741250
# gauss_rifle                    65.450000   51.892500
# gauss_cannon_turret            71.087500   56.362232
# thermal_shok_launcher          68.970000   63.147857
# sonic_blasta_rifle             81.510000   66.954643
# pwt_cannon_turret             115.500000   67.650000
# sonic_pistol                   96.360000   79.152857
# thermal_tazer                  96.800000   88.628571
# sonic_cannon                  117.975000   96.908036
# sonic_cannon_turret           128.865000  105.853393
# disruptor_pulse_launcher      207.900000  121.770000
# vibro_blade                   528.000000  302.657143
# thermic_lance                 580.800000  332.922857
# heavy_thermic_lance           792.000000  453.985714

# %%
ax = average_damages_expected.plot.bar(title="Damage per turn on average target", legend=False)
ax.legend(["Max", "Average"])
ax.xaxis.get_label().set_visible(False)
ax.set_ylabel("Damage")
# Out:
# Text(0, 0.5, 'Damage')

# %% [markdown]
# #### Damage Per Time Unit

# %%
weapon_damages_per_tu_targets = weapon_data_targets.groupby(["weapon", "target"]).mean()
weapon_damages_per_tu_targets = weapon_damages_per_tu_targets[["target_damage_per_time_unit"]]
weapon_damages_per_tu_targets = weapon_damages_per_tu_targets.rename(columns={"target_damage_per_time_unit": "damage_per_time_unit"})
weapon_damages_per_tu_targets = weapon_damages_per_tu_targets.sort_values(by=["damage_per_time_unit"])

# %%
weapon_damages_per_tu_targets_average = weapon_damages_per_tu_targets.groupby(["weapon"]).mean()
weapon_damages_per_tu_targets_average = weapon_damages_per_tu_targets_average.sort_values(by=["damage_per_time_unit"])

# %%
weapon_damages_per_tu_targets_max = weapon_damages_per_tu_targets.groupby(["weapon"]).max()
weapon_damages_per_tu_targets_max = weapon_damages_per_tu_targets_max.sort_values(by=["damage_per_time_unit"])

# %%
weapon_damages_per_tu_targets_expected = weapon_damages_per_tu_targets_max.merge(weapon_damages_per_tu_targets_average, on="weapon")
weapon_damages_per_tu_targets_expected = weapon_damages_per_tu_targets_expected.rename(columns={"damage_per_time_unit_x": "max", "damage_per_time_unit_y": "average"})
weapon_damages_per_tu_targets_expected = weapon_damages_per_tu_targets_expected.sort_values(by=["average"])
weapon_damages_per_tu_targets_expected
# Out:
#                                     max   average
# weapon
# jet_harpoon                    0.226190  0.191454
# dart_gun                       0.560000  0.474000
# magna_blast_grenade            1.000000  0.585714
# hidro_jet_cannon               1.284722  0.809113
# particle_disturbance_grenade   1.400000  0.820000
# gas_cannon                     1.312917  0.987768
# aqua_jet_cannon_turret         1.733333  1.015238
# gas_cannon_turret              1.284091  1.086891
# gauss_pistol                   1.400000  1.110000
# heavy_gauss                    1.406250  1.114955
# magna_pack_explosive           2.000000  1.171429
# gauss_rifle                    1.500000  1.189286
# torpedo_launcher               2.093750  1.322768
# sonic_pulser                   2.400000  1.405714
# pwt_cannon_turret              3.181818  1.863636
# gauss_cannon_turret            2.400000  1.902857
# sonic_blasta_rifle             2.375000  1.950893
# thermal_tazer                  2.200000  2.014286
# thermal_shok_launcher          2.262857  2.071837
# sonic_pistol                   2.560000  2.102857
# sonic_cannon                   2.674286  2.196735
# disruptor_pulse_launcher       4.200000  2.460000
# sonic_cannon_turret            3.300000  2.710714
# thermic_lance                 14.666667  8.407143
# heavy_thermic_lance           15.000000  8.598214
# vibro_blade                   16.000000  9.171429

# %%
ax = weapon_damages_per_tu_targets_expected.plot.bar(title="Damage per time unit on average target", legend=False)
ax.legend(["Max", "Average"])
ax.xaxis.get_label().set_visible(False)
ax.set_ylabel("Ratio")
# Out:
# Text(0, 0.5, 'Ratio')

# %% [markdown]
# #### Terrain

# %%
weapon_damages_terrain = weapon_damages_targets.xs("terrain", level="target")
weapon_damages_terrain = weapon_damages_terrain.sort_values(by=["turn_damage"])

# %%
ax = weapon_damages_terrain.plot.bar(title="Damage per turn to terrain", legend=False)
ax.xaxis.get_label().set_visible(False)
ax.set_ylabel("Damage")
# Out:
# Text(0, 0.5, 'Damage')

# %% [markdown]
# #### Unarmored

# %%
weapon_damages_unarmored = weapon_damages_targets.xs("unarmored", level="target")
weapon_damages_unarmored = weapon_damages_unarmored.sort_values(by=["turn_damage"])

# %%
ax = weapon_damages_unarmored.plot.bar(title="Damage per turn to unarmored", legend=False)
ax.xaxis.get_label().set_visible(False)
ax.set_ylabel("Damage")
# Out:
# Text(0, 0.5, 'Damage')

# %% [markdown]
# #### Plastic Aqua Armor

# %%
weapon_damages_armor = weapon_damages_targets.xs("plastic_aqua_armor", level="target")
weapon_damages_armor = weapon_damages_armor.sort_values(by=["turn_damage"])

# %%
ax = weapon_damages_unarmored.plot.bar(title="Damage per turn to plastic aqua armor", legend=False)
ax.xaxis.get_label().set_visible(False)
ax.set_ylabel("Damage")
# Out:
# Text(0, 0.5, 'Damage')

# %% [markdown]
# #### Ion Armor

# %%
weapon_damages_power_suit = weapon_damages_targets.xs("ion_armor", level="target")
weapon_damages_power_suit = weapon_damages_power_suit.sort_values(by=["turn_damage"])

# %%
ax = weapon_damages_power_suit.plot.bar(title="Damage per turn to ion armor", legend=False)
ax.xaxis.get_label().set_visible(False)
ax.set_ylabel("Damage")
# Out:
# Text(0, 0.5, 'Damage')

# %% [markdown]
# #### Tank

# %%
weapon_damages_tank = weapon_damages_targets.xs("tank", level="target")
weapon_damages_tank = weapon_damages_tank.sort_values(by=["turn_damage"])

# %%
ax = weapon_damages_tank.plot.bar(title="Damage per turn to tank", legend=False)
ax.xaxis.get_label().set_visible(False)
ax.set_ylabel("Damage")
# Out:
# Text(0, 0.5, 'Damage')

# %% [markdown]
# #### Gillman

# %%
weapon_damages_snakeman = weapon_damages_targets.xs("gillman", level="target")
weapon_damages_snakeman = weapon_damages_snakeman.sort_values(by=["turn_damage"])

# %%
ax = weapon_damages_snakeman.plot.bar(title="Damage per turn to gillman", legend=False)
ax.xaxis.get_label().set_visible(False)
ax.set_ylabel("Damage")
# Out:
# Text(0, 0.5, 'Damage')

# %% [markdown]
# #### Deep One

# %%
weapon_damages_ethereal = weapon_damages_targets.xs("deep_one", level="target")
weapon_damages_ethereal = weapon_damages_ethereal.sort_values(by=["turn_damage"])

# %%
ax = weapon_damages_ethereal.plot.bar(title="Damage per turn to deep one", legend=False)
ax.xaxis.get_label().set_visible(False)
ax.set_ylabel("Damage")
# Out:
# Text(0, 0.5, 'Damage')

# %% [markdown]
# #### Tasoth

# %%
weapon_damages_muton = weapon_damages_targets.xs("tasoth", level="target")
weapon_damages_muton = weapon_damages_muton.sort_values(by=["turn_damage"])

# %%
ax = weapon_damages_muton.plot.bar(title="Damage per turn to tasoth", legend=False)
ax.xaxis.get_label().set_visible(False)
ax.set_ylabel("Damage")
# Out:
# Text(0, 0.5, 'Damage')

# %% [markdown]
# #### Calcinite

# %%
weapon_damages_silacoid = weapon_damages_targets.xs("calcinite", level="target")
weapon_damages_silacoid = weapon_damages_silacoid.sort_values(by=["turn_damage"])

# %%
ax = weapon_damages_silacoid.plot.bar(title="Damage per turn to calcinite", legend=False)
ax.xaxis.get_label().set_visible(False)
ax.set_ylabel("Damage")
# Out:
# Text(0, 0.5, 'Damage')

# %% [markdown]
# #### Tentaculat

# %%
weapon_damages_chryssalid = weapon_damages_targets.xs("tentaculat", level="target")
weapon_damages_chryssalid = weapon_damages_chryssalid.sort_values(by=["turn_damage"])

# %%
ax = weapon_damages_chryssalid.plot.bar(title="Damage per turn to tentaculat", legend=False)
ax.xaxis.get_label().set_visible(False)
ax.set_ylabel("Damage")
# Out:
# Text(0, 0.5, 'Damage')

# %% [markdown]
# #### Lobsterman

# %%
weapon_damages_reaper = weapon_damages_targets.xs("lobsterman", level="target")
weapon_damages_reaper = weapon_damages_reaper.sort_values(by=["turn_damage"])

# %%
ax = weapon_damages_reaper.plot.bar(title="Damage per turn to lobsterman", legend=False)
ax.xaxis.get_label().set_visible(False)
ax.set_ylabel("Damage")
# Out:
# Text(0, 0.5, 'Damage')

# %% [markdown]
# #### Xarquid

# %%
weapon_damages_sectopod = weapon_damages_targets.xs("xarquid", level="target")
weapon_damages_sectopod = weapon_damages_sectopod.sort_values(by=["turn_damage"])

# %%
ax = weapon_damages_sectopod.plot.bar(title="Damage per turn to xarquid", legend=False)
ax.xaxis.get_label().set_visible(False)
ax.set_ylabel("Damage")
# Out:
# Text(0, 0.5, 'Damage')

# %% [markdown]
# #### Hallucinoid

# %%
weapon_damages_cyberdisk = weapon_damages_targets.xs("hallucinoid", level="target")
weapon_damages_cyberdisk = weapon_damages_cyberdisk.sort_values(by=["turn_damage"])

# %%
ax = weapon_damages_cyberdisk.plot.bar(title="Damage per turn to hallucinoid", legend=False)
ax.xaxis.get_label().set_visible(False)
ax.set_ylabel("Damage")
# Out:
# Text(0, 0.5, 'Damage')

# %% [markdown]
# #### Zombie

# %%
weapon_damages_zombie = weapon_damages_targets.xs("zombie", level="target")
weapon_damages_zombie = weapon_damages_zombie.sort_values(by=["turn_damage"])

# %%
ax = weapon_damages_zombie.plot.bar(title="Damage per turn to zombie", legend=False)
ax.xaxis.get_label().set_visible(False)
ax.set_ylabel("Damage")
# Out:
# Text(0, 0.5, 'Damage')
